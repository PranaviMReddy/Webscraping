# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\programdata\anaconda3\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\pranavi's pc\appdata\roaming\python\python37\site-packages (from selenium) (1.25.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importing Required Libraries
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import requests
import os
from bs4 import BeautifulSoup as bs
import shutil

# %%
#Make a function to start web driver
def initialiseChromeDriver():
    driver = webdriver.Chrome(executable_path= r'C:\Program Files\chromedriver\chromedriver')
    #provide the path of chromedriver into executable_path
    driver.get("https://www.amazon.in/ref=nav_logo")
    #provide amazon homepage Url
    return driver

def fill_form(driver, search_argument):
    '''Finds all the input tags in form and makes a POST requests.'''
    search_field = driver.find_element_by_id('twotabsearchtextbox')
    #Inspecting the search field using inspect element and adding the "id"
    search_field.send_keys(search_argument)
    #look for the search button and click it
    driver.find_element_by_class_name('nav-input')\
    .click()

#creating directory to store images
def make_directory(dirname):
    current_path= os.getcwd()
    path= os.path.join(current_path, dirname)
    if not os.path.exists(path):
        os.makedirs(path)

def startScrapingContent(driver):
    ##beautiful soup##
    html = driver.page_source #html page source
    soup = BeautifulSoup(html)
    
    urls = []
    #make a dictionary to store Urls
    
    for tag in soup.find_all("a", {"class":"a-link-normal"}):
        #Use inspect element to find the class of product image and find all of them using beautifulsoup
        img = tag.find_all('img')
        #print (str(len(img)) + "images found.")
        for i in img:
            link = i['src']
            urls.append(link)
        
        
    #navigating to next page
    driver.find_element_by_class_name('a-normal')\
    .click()
    
   
    #Adding next page image urls to URLs
    for tag in soup.find_all("a", {"class":"a-link-normal"}):
        img = tag.find_all('img')
        #print (str(len(img)) + "images found.")
        for i in img:
            link = i['src']
            urls.append(link)
    
    #saving images
    for index,link in enumerate(urls):
        print("downloading {0} of {1} images".format(index+1, len(urls)))
        response= requests.get(link)
        with open('img_{0}.jpeg'.format(index),"wb") as file:
            file.write(response.content)

            
#Use created functions to search and download images for different product search

#Now dowloading Women Saree Images
driver = initialiseChromeDriver()
fill_form(driver, 'women sarees')
make_directory('sarees')
os.chdir("C:\\Users\\Pranavi's PC\\webscraping_amazon\\sarees")
startScrapingContent(driver)
driver.close()
# Out:
# downloading 1 of 106 images
# downloading 2 of 106 images
# downloading 3 of 106 images
# downloading 4 of 106 images
# downloading 5 of 106 images
# downloading 6 of 106 images
# downloading 7 of 106 images
# downloading 8 of 106 images
# downloading 9 of 106 images
# downloading 10 of 106 images
# downloading 11 of 106 images
# downloading 12 of 106 images
# downloading 13 of 106 images
# downloading 14 of 106 images
# downloading 15 of 106 images
# downloading 16 of 106 images
# downloading 17 of 106 images
# downloading 18 of 106 images
# downloading 19 of 106 images
# downloading 20 of 106 images
# downloading 21 of 106 images
# downloading 22 of 106 images
# downloading 23 of 106 images
# downloading 24 of 106 images
# downloading 25 of 106 images
# downloading 26 of 106 images
# downloading 27 of 106 images
# downloading 28 of 106 images
# downloading 29 of 106 images
# downloading 30 of 106 images
# downloading 31 of 106 images
# downloading 32 of 106 images
# downloading 33 of 106 images
# downloading 34 of 106 images
# downloading 35 of 106 images
# downloading 36 of 106 images
# downloading 37 of 106 images
# downloading 38 of 106 images
# downloading 39 of 106 images
# downloading 40 of 106 images
# downloading 41 of 106 images
# downloading 42 of 106 images
# downloading 43 of 106 images
# downloading 44 of 106 images
# downloading 45 of 106 images
# downloading 46 of 106 images
# downloading 47 of 106 images
# downloading 48 of 106 images
# downloading 49 of 106 images
# downloading 50 of 106 images
# downloading 51 of 106 images
# downloading 52 of 106 images
# downloading 53 of 106 images
# downloading 54 of 106 images
# downloading 55 of 106 images
# downloading 56 of 106 images
# downloading 57 of 106 images
# downloading 58 of 106 images
# downloading 59 of 106 images
# downloading 60 of 106 images
# downloading 61 of 106 images
# downloading 62 of 106 images
# downloading 63 of 106 images
# downloading 64 of 106 images
# downloading 65 of 106 images
# downloading 66 of 106 images
# downloading 67 of 106 images
# downloading 68 of 106 images
# downloading 69 of 106 images
# downloading 70 of 106 images
# downloading 71 of 106 images
# downloading 72 of 106 images
# downloading 73 of 106 images
# downloading 74 of 106 images
# downloading 75 of 106 images
# downloading 76 of 106 images
# downloading 77 of 106 images
# downloading 78 of 106 images
# downloading 79 of 106 images
# downloading 80 of 106 images
# downloading 81 of 106 images
# downloading 82 of 106 images
# downloading 83 of 106 images
# downloading 84 of 106 images
# downloading 85 of 106 images
# downloading 86 of 106 images
# downloading 87 of 106 images
# downloading 88 of 106 images
# downloading 89 of 106 images
# downloading 90 of 106 images
# downloading 91 of 106 images
# downloading 92 of 106 images
# downloading 93 of 106 images
# downloading 94 of 106 images
# downloading 95 of 106 images
# downloading 96 of 106 images
# downloading 97 of 106 images
# downloading 98 of 106 images
# downloading 99 of 106 images
# downloading 100 of 106 images
# downloading 101 of 106 images
# downloading 102 of 106 images
# downloading 103 of 106 images
# downloading 104 of 106 images
# downloading 105 of 106 images
# downloading 106 of 106 images

# %%
#Downloading Men Trousers

driver = initialiseChromeDriver()
fill_form(driver, 'Men Trousers')
os.chdir("C:\\Users\\Pranavi's PC\\webscraping_amazon")
make_directory('Trousers')
os.chdir("C:\\Users\\Pranavi's PC\\webscraping_amazon\\Trousers")
startScrapingContent(driver)
driver.close()
# Out:
# downloading 1 of 120 images
# downloading 2 of 120 images
# downloading 3 of 120 images
# downloading 4 of 120 images
# downloading 5 of 120 images
# downloading 6 of 120 images
# downloading 7 of 120 images
# downloading 8 of 120 images
# downloading 9 of 120 images
# downloading 10 of 120 images
# downloading 11 of 120 images
# downloading 12 of 120 images
# downloading 13 of 120 images
# downloading 14 of 120 images
# downloading 15 of 120 images
# downloading 16 of 120 images
# downloading 17 of 120 images
# downloading 18 of 120 images
# downloading 19 of 120 images
# downloading 20 of 120 images
# downloading 21 of 120 images
# downloading 22 of 120 images
# downloading 23 of 120 images
# downloading 24 of 120 images
# downloading 25 of 120 images
# downloading 26 of 120 images
# downloading 27 of 120 images
# downloading 28 of 120 images
# downloading 29 of 120 images
# downloading 30 of 120 images
# downloading 31 of 120 images
# downloading 32 of 120 images
# downloading 33 of 120 images
# downloading 34 of 120 images
# downloading 35 of 120 images
# downloading 36 of 120 images
# downloading 37 of 120 images
# downloading 38 of 120 images
# downloading 39 of 120 images
# downloading 40 of 120 images
# downloading 41 of 120 images
# downloading 42 of 120 images
# downloading 43 of 120 images
# downloading 44 of 120 images
# downloading 45 of 120 images
# downloading 46 of 120 images
# downloading 47 of 120 images
# downloading 48 of 120 images
# downloading 49 of 120 images
# downloading 50 of 120 images
# downloading 51 of 120 images
# downloading 52 of 120 images
# downloading 53 of 120 images
# downloading 54 of 120 images
# downloading 55 of 120 images
# downloading 56 of 120 images
# downloading 57 of 120 images
# downloading 58 of 120 images
# downloading 59 of 120 images
# downloading 60 of 120 images
# downloading 61 of 120 images
# downloading 62 of 120 images
# downloading 63 of 120 images
# downloading 64 of 120 images
# downloading 65 of 120 images
# downloading 66 of 120 images
# downloading 67 of 120 images
# downloading 68 of 120 images
# downloading 69 of 120 images
# downloading 70 of 120 images
# downloading 71 of 120 images
# downloading 72 of 120 images
# downloading 73 of 120 images
# downloading 74 of 120 images
# downloading 75 of 120 images
# downloading 76 of 120 images
# downloading 77 of 120 images
# downloading 78 of 120 images
# downloading 79 of 120 images
# downloading 80 of 120 images
# downloading 81 of 120 images
# downloading 82 of 120 images
# downloading 83 of 120 images
# downloading 84 of 120 images
# downloading 85 of 120 images
# downloading 86 of 120 images
# downloading 87 of 120 images
# downloading 88 of 120 images
# downloading 89 of 120 images
# downloading 90 of 120 images
# downloading 91 of 120 images
# downloading 92 of 120 images
# downloading 93 of 120 images
# downloading 94 of 120 images
# downloading 95 of 120 images
# downloading 96 of 120 images
# downloading 97 of 120 images
# downloading 98 of 120 images
# downloading 99 of 120 images
# downloading 100 of 120 images
# downloading 101 of 120 images
# downloading 102 of 120 images
# downloading 103 of 120 images
# downloading 104 of 120 images
# downloading 105 of 120 images
# downloading 106 of 120 images
# downloading 107 of 120 images
# downloading 108 of 120 images
# downloading 109 of 120 images
# downloading 110 of 120 images
# downloading 111 of 120 images
# downloading 112 of 120 images
# downloading 113 of 120 images
# downloading 114 of 120 images
# downloading 115 of 120 images
# downloading 116 of 120 images
# downloading 117 of 120 images
# downloading 118 of 120 images
# downloading 119 of 120 images
# downloading 120 of 120 images

# %%
#Downloading Men Jeans
driver = initialiseChromeDriver()
fill_form(driver, 'Men Jeans')
os.chdir("C:\\Users\\Pranavi's PC\\webscraping_amazon")
make_directory('Men Jeans')
os.chdir("C:\\Users\\Pranavi's PC\\webscraping_amazon\\Men Jeans")
startScrapingContent(driver)
driver.close()
# Out:
# downloading 1 of 128 images
# downloading 2 of 128 images
# downloading 3 of 128 images
# downloading 4 of 128 images
# downloading 5 of 128 images
# downloading 6 of 128 images
# downloading 7 of 128 images
# downloading 8 of 128 images
# downloading 9 of 128 images
# downloading 10 of 128 images
# downloading 11 of 128 images
# downloading 12 of 128 images
# downloading 13 of 128 images
# downloading 14 of 128 images
